# %% [markdown]
# **Imports**

# %%
import pyspark.sql.functions as F
from pyspark.sql.window import Window

# %% [markdown]
# **Reading The Table**

# %%
fact_membership_df = spark.read.table("rental.bike_rental_silver.membership")

# %%
fact_membership_df = spark.read.table("rental.bike_rental_silver.membership").select("customer_id","id","membership_type_id","start_date","end_date","total_paid").withColumnRenamed("id","membership_id")

# %% [markdown]
# **Writing to Gold**

# %%
fact_membership_df.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable("rental.bike_rental_gold.fact_membership")
